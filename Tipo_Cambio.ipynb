# %%
import pandas as pd

# %%
excel = pd.read_excel(r'C:\Users\JENNY\Google Drive\Datos\BLOG_PERSONAL\Archivo.xlsx', sheetname=0, 
              skiprows = 6)

# %%
excel.head()
# Out:
#            Fecha  Córdobas por USD
# 0  01-January-00           12.3202
# 1  02-January-00           12.3222
# 2  03-January-00           12.3242
# 3  04-January-00           12.3261
# 4  05-January-00           12.3281

# %%
excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7192 entries, 0 to 7191
# Data columns (total 2 columns):
# Fecha               7192 non-null object
# Córdobas por USD    7192 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 112.4+ KB

# %%
excel.loc[:,'Fecha'] = excel.loc[:,'Fecha'].apply(pd.to_datetime)

# %%
excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7192 entries, 0 to 7191
# Data columns (total 2 columns):
# Fecha               7192 non-null datetime64[ns]
# Córdobas por USD    7192 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 112.4 KB

# %%
excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7192 entries, 0 to 7191
# Data columns (total 2 columns):
# Fecha               7192 non-null datetime64[ns]
# Córdobas por USD    7192 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 112.4 KB

# %%
excel
# Out:
#           Fecha  Córdobas por USD
# 0    2000-01-01           12.3202
# 1    2000-01-02           12.3222
# 2    2000-01-03           12.3242
# 3    2000-01-04           12.3261
# 4    2000-01-05           12.3281
# 5    2000-01-06           12.3301
# 6    2000-01-07           12.3320
# 7    2000-01-10           12.3379
# 8    2000-01-11           12.3399
# 9    2000-01-12           12.3419
# 10   2000-01-13           12.3438
# 11   2000-01-14           12.3458
# 12   2000-01-15           12.3478
# 13   2000-01-16           12.3498
# 14   2000-01-17           12.3517
# 15   2000-01-18           12.3537
# 16   2000-01-19           12.3557
# 17   2000-01-20           12.3576
# 18   2000-01-21           12.3596
# 19   2000-01-22           12.3616
# 20   2000-01-23           12.3636
# 21   2000-01-24           12.3655
# 22   2000-01-25           12.3675
# 23   2000-01-26           12.3695
# 24   2000-01-27           12.3715
# 25   2000-01-28           12.3734
# 26   2000-01-29           12.3754
# 27   2000-01-30           12.3774
# 28   2000-01-31           12.3794
# 29   2000-02-01           12.3812
# ...         ...               ...
# 7162 2019-10-02           33.5410
# 7163 2019-10-03           33.5455
# 7164 2019-10-04           33.5500
# 7165 2019-10-05           33.5545
# 7166 2019-10-06           33.5590
# 7167 2019-10-07           33.5635
# 7168 2019-10-08           33.5680
# 7169 2019-10-09           33.5724
# 7170 2019-10-10           33.5769
# 7171 2019-10-11           33.5814
# 7172 2019-10-12           33.5859
# 7173 2019-10-13           33.5904
# 7174 2019-10-14           33.5949
# 7175 2019-10-15           33.5994
# 7176 2019-10-16           33.6039
# 7177 2019-10-17           33.6084
# 7178 2019-10-18           33.6129
# 7179 2019-10-19           33.6173
# 7180 2019-10-20           33.6218
# 7181 2019-10-21           33.6263
# 7182 2019-10-22           33.6308
# 7183 2019-10-23           33.6353
# 7184 2019-10-24           33.6398
# 7185 2019-10-25           33.6443
# 7186 2019-10-26           33.6488
# 7187 2019-10-27           33.6533
# 7188 2019-10-28           33.6578
# 7189 2019-10-29           33.6623
# 7190 2019-10-30           33.6668
# 7191 2019-10-31           33.6713
#
# [7192 rows x 2 columns]

# %%
tipo_cambio = excel.groupby(pd.Grouper(key='Fecha', freq='1M')).last()

# %%
tipo_cambio.tail()
# Out:
#             Córdobas por USD
# Fecha
# 2019-06-30           33.1222
# 2019-07-31           33.2598
# 2019-08-31           33.3979
# 2019-09-30           33.5321
# 2019-10-31           33.6713

# %%
tipo_cambio.loc['2019-08-31']
# Out:
# Córdobas por USD    33.3979
# Name: 2019-08-31 00:00:00, dtype: float64

# %%
tipo_cambio.loc['2013-01-31' : '2013-12-31']
# Out:
#             Córdobas por USD
# Fecha
# 2013-01-31           24.2257
# 2013-02-28           24.3165
# 2013-03-31           24.4175
# 2013-04-30           24.5156
# 2013-05-31           24.6174
# 2013-06-30           24.7163
# 2013-07-31           24.8190
# 2013-08-31           24.9220
# 2013-09-30           25.0222
# 2013-10-31           25.1261
# 2013-11-30           25.2270
# 2013-12-31           25.3318

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(tipo_cambio)
plt.show()
